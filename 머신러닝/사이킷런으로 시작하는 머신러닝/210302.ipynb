# %% [markdown]
# # Kaggle에서 데이터 다운로드 방법
#
#
# ### 구글 드라이브와 Colab 연동

# %%
# from google.colab import auth
# auth.authenticate_user()

# # colab에서 drive란 폴더를 만든 후, 우리 구글 드라이브의 root와 drive 폴더를 연결(mount)
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Kaggle API Json Key 파일 다운
#
# -kaggle 에서 로그인 하신다음에 Account로 들어가서 Create API token을 받아서 구글 드라이브에 올린 후에 마운팅 한 다음에 다음 코드를 실행

# %%
#make dictory
# !mkdir -p ~/.kaggle
#move file
# !mv /content/drive/MyDrive/kaggle.json ~/.kaggle/
#chmod로 보안 문제 해결
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Titaninc 기준
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 21.8MB/s]
# ...
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 28.0MB/s]
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 9.15MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(train.shape, test.shape)
# Out:
# (891, 12) (418, 11)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def bar_chart(feature):
  surived = train[train['Survived']==1][feature].value_counts()
  dead =train[train['Survived']==0][feature].value_counts()
  df = pd.DataFrame([surived,dead])
  df.index = ['Survied', 'Dead']
  df.plot(kind = 'bar',figsize = (10,5))

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
sex_mapping = {'male':0, 'female':1}

train_test_data = [train,test]

# %%
for dataset in train_test_data:
  dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
train['Age'].fillna(train['Age'].median(), inplace=True)
test['Age'].fillna(test['Age'].median(), inplace=True)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
train['Age'].fillna(train['Age'].mean(), inplace=True)
test['Age'].fillna(test['Age'].mean(), inplace=True)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
train['Age'].fillna(train['Age'].quantile(0.25), inplace=True)
test['Age'].fillna(test['Age'].quantile(0.25), inplace=True)

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0              1         0       3  ...   7.2500    NaN         S
# 1              2         1       1  ...  71.2833    C85         C
# 2              3         1       3  ...   7.9250    NaN         S
# 3              4         1       1  ...  53.1000   C123         S
# 4              5         0       3  ...   8.0500    NaN         S
# ..           ...       ...     ...  ...      ...    ...       ...
# 886          887         0       2  ...  13.0000    NaN         S
# 887          888         1       1  ...  30.0000    B42         S
# 888          889         0       3  ...  23.4500    NaN         S
# 889          890         1       1  ...  30.0000   C148         C
# 890          891         0       3  ...   7.7500    NaN         Q
#
# [891 rows x 12 columns]

# %%
train.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# D              3
#               ..
# A34            1
# B78            1
# D7             1
# B79            1
# E40            1
# Name: Cabin, Length: 147, dtype: int64

# %%
feature_drop = ['Ticket','Pclass','Name','Parch','Ticket','Embarked','Cabin']
train_drop = train.drop(feature_drop,axis = 1)
test_drop = test.drop(feature_drop,axis = 1)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0              1         0       3  ...   7.2500    NaN         S
# 1              2         1       1  ...  71.2833    C85         C
# 2              3         1       3  ...   7.9250    NaN         S
# 3              4         1       1  ...  53.1000   C123         S
# 4              5         0       3  ...   8.0500    NaN         S
# ..           ...       ...     ...  ...      ...    ...       ...
# 886          887         0       2  ...  13.0000    NaN         S
# 887          888         1       1  ...  30.0000    B42         S
# 888          889         0       3  ...  23.4500    NaN         S
# 889          890         1       1  ...  30.0000   C148         C
# 890          891         0       3  ...   7.7500    NaN         Q
#
# [891 rows x 12 columns]

# %%
train_lable = train_drop['Survived']
train_data = train.drop('Survived', axis = 1)

# %%
feature1 = ['PassengerId','Name','Parch','Cabin','Embarked','Pclass','Ticket']
train_data =train_data.drop(feature1,axis=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
K_fold = KFold(n_splits=10,shuffle=True, random_state=777)

# %%
import warnings
warnings.filterwarnings("ignore")
Knn_clf = KNeighborsClassifier(n_neighbors=500)
scoring = cross_val_score(Knn_clf, train_data,train_lable,cv=K_fold,n_jobs=1, scoring='accuracy')

print(scoring)
# Out:
# [0.6        0.75280899 0.48314607 0.5505618  0.64044944 0.65168539
#  0.62921348 0.60674157 0.66292135 0.62921348]

# %%
from sklearn.linear_model import LinearRegression

Linear = LinearRegression().fit(train_data,train_lable)
print(Linear.score(train_data, train_lable))
# Out:
# 0.3412590775184373

# %%
feature_test = ['PassengerId','Pclass','Name','Parch','Ticket','Cabin','Embarked']
test_drop = test.drop(feature_test, axis = 1)

# %%
test_drop.isnull().sum()
# Out:
# Sex      0
# Age      0
# SibSp    0
# Fare     1
# dtype: int64

# %%
test_drop['Fare'].fillna(test_drop['Fare'].mean(), inplace=True)

# %%
test_drop.isnull().sum()
# Out:
# Sex      0
# Age      0
# SibSp    0
# Fare     0
# dtype: int64

# %%
test_drop
# Out:
#      Sex   Age  SibSp      Fare
# 0      0  34.5      0    7.8292
# 1      1  47.0      1    7.0000
# 2      0  62.0      0    9.6875
# 3      0  27.0      0    8.6625
# 4      1  22.0      1   12.2875
# ..   ...   ...    ...       ...
# 413    0  27.0      0    8.0500
# 414    1  39.0      0  108.9000
# 415    0  38.5      0    7.2500
# 416    0  27.0      0    8.0500
# 417    0  27.0      1   22.3583
#
# [418 rows x 4 columns]

# %%
train_data
# Out:
#      Sex   Age  SibSp     Fare
# 0      0  22.0      1   7.2500
# 1      1  38.0      1  71.2833
# 2      1  26.0      0   7.9250
# 3      1  35.0      1  53.1000
# 4      0  35.0      0   8.0500
# ..   ...   ...    ...      ...
# 886    0  27.0      0  13.0000
# 887    1  19.0      0  30.0000
# 888    1  28.0      1  23.4500
# 889    0  26.0      0  30.0000
# 890    0  32.0      0   7.7500
#
# [891 rows x 4 columns]

# %%
prediction = Linear.predict(test_drop)
Linear.score(train_data,train_lable)
# Out:
# 0.3412590775184373

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
#   0% 0.00/441k [00:00<?, ?B/s]
# 100% 441k/441k [00:00<00:00, 64.6MB/s]
# data_description.txt: Skipping, found more recently modified local copy (use --force to force download)
# ...
#   0% 0.00/450k [00:00<?, ?B/s]
# 100% 450k/450k [00:00<00:00, 29.1MB/s]
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
train.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(10,5)) 

sns.displot(train.SalePrice,bins = 50)

# %%
train = pd.DataFrame(train)
test = pd.DataFrame(test)

# %%
train.plot.scatter(x = 'LotFrontage',y = 'SalePrice')

# %%
train_corr = train.corr()

f,ax = plt.subplots(figsize = (20,9))

sns.heatmap(train_corr, annot= True)

# %%
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(train[cols], size = 2.5)

# %%
train.isnull().sum().sum()
# Out:
# 6965

# %%
total = train.isnull().sum().sort_values(ascending = False)
percent = (train.isnull().sum() / train.isnull().count()).sort_values(ascending = False)
print(percent)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(10)
# Out:
# PoolQC           0.995205
# MiscFeature      0.963014
# Alley            0.937671
# Fence            0.807534
# FireplaceQu      0.472603
#                    ...
# CentralAir       0.000000
# SaleCondition    0.000000
# Heating          0.000000
# TotalBsmtSF      0.000000
# Id               0.000000
# Length: 81, dtype: float64
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479

# %%
missing_data['Percent'] > 0.7
# Out:
# PoolQC            True
# MiscFeature       True
# Alley             True
# Fence             True
# FireplaceQu      False
#                  ...
# CentralAir       False
# SaleCondition    False
# Heating          False
# TotalBsmtSF      False
# Id               False
# Name: Percent, Length: 81, dtype: bool

# %%
all_data = train.drop((missing_data[missing_data['Percent'] > 0.3]).index,axis = 1)

# %%
all_data
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 76 columns]

# %%
corrmat = train.corr()
top_corrmat = corrmat.index[abs(corrmat['SalePrice']>0.3)]
top_corrmat
# Out:
# Index(['LotFrontage', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea',
#        'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'SalePrice'],
#       dtype='object')

# %%
plt.figure(figsize=(13,10))
sns.heatmap(train[top_corrmat].corr(), annot=True)

# %%
train = pd.DataFrame(train)

# %%
train_df = train[top_corrmat]

# %%
train_df
# Out:
#       LotFrontage  OverallQual  YearBuilt  ...  WoodDeckSF  OpenPorchSF  SalePrice
# 0            65.0            7       2003  ...           0           61     208500
# 1            80.0            6       1976  ...         298            0     181500
# 2            68.0            7       2001  ...           0           42     223500
# 3            60.0            7       1915  ...           0           35     140000
# 4            84.0            8       2000  ...         192           84     250000
# ...           ...          ...        ...  ...         ...          ...        ...
# 1455         62.0            6       1999  ...           0           40     175000
# 1456         85.0            6       1978  ...         349            0     210000
# 1457         66.0            7       1941  ...           0           60     266500
# 1458         68.0            5       1950  ...         366            0     142125
# ...

# %%
train_y_label = train_df['SalePrice']
train_df.drop(['SalePrice'],axis = 1, inplace = True)

# %%
train_df
# Out:
#       LotFrontage  OverallQual  YearBuilt  ...  GarageArea  WoodDeckSF  OpenPorchSF
# 0            65.0            7       2003  ...         548           0           61
# 1            80.0            6       1976  ...         460         298            0
# 2            68.0            7       2001  ...         608           0           42
# 3            60.0            7       1915  ...         642           0           35
# 4            84.0            8       2000  ...         836         192           84
# ...           ...          ...        ...  ...         ...         ...          ...
# 1455         62.0            6       1999  ...         460           0           40
# 1456         85.0            6       1978  ...         500         349            0
# 1457         66.0            7       1941  ...         252           0           60
# 1458         68.0            5       1950  ...         240         366            0
# ...

# %%
test
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
top_corrmat = list(top_corrmat)
top_corrmat = top_corrmat[:18]

# %%
top_corrmat
# Out:
# ['LotFrontage',
#  'OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF']

# %%
test_df = test[top_corrmat]

# %%
test_df
# Out:
#       LotFrontage  OverallQual  YearBuilt  ...  GarageArea  WoodDeckSF  OpenPorchSF
# 0            80.0            5       1961  ...       730.0         140            0
# 1            81.0            6       1958  ...       312.0         393           36
# 2            74.0            5       1997  ...       482.0         212           34
# 3            78.0            6       1998  ...       470.0         360           36
# 4            43.0            8       1992  ...       506.0           0           82
# ...           ...          ...        ...  ...         ...         ...          ...
# 1454         21.0            4       1970  ...         0.0           0            0
# 1455         21.0            4       1970  ...       286.0           0           24
# 1456        160.0            5       1960  ...       576.0         474            0
# 1457         62.0            5       1992  ...         0.0          80           32
# ...

# %%
train_df.shape,test_df.shape
# Out:
# ((1460, 18), (1459, 18))

# %%
test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64
